# %% [markdown]
# <a href="https://colab.research.google.com/github/Luis-h-github/Luis04-09-2024/blob/main/C%C3%B3pia_de_Trabalho_MassakisSQLITE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Largura = float(input("Digite a largura do vão em centimetro: "))
cores = ["preto", "branco", "fosco", "champanhe", "bronze"]
numero_cor = [1, 2, 3, 4, 5]
print("\n=== Escolha a cor do Kit ===")
print("1. preto")
print("2. branco")
print("3. fosco")
print("4. champanhe")
print("5. bronze")
Cor = input("Digite a cor do kit evidence door: ").lower()  # Adicionado o método .lower() corretamente


while Cor in cores or Cor in [str(num) for num in numero_cor]:  # Convertendo números para strings
    Vidro = float(input("Digite a quantidade de vidro: "))
    fechadura = ["lateral", "central"]
    numero_fechadura = [1, 2]
    print("\n=== Escolha modelo da fechadura ===")
    print("1. lateral")
    print("2. central")
    Fechadura = input("Digite a posição da fechadura: ").lower()  # Adicionado o método .lower() corretamente


    while Fechadura in fechadura or Fechadura in [str(num) for num in numero_fechadura]:
        # Determina o modelo do Kit com base nos dados solicitados.
        if Largura <= 150 and Cor == "preto" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - preto - fechadura lateral")

        elif Largura <= 150 and Cor == "branco" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - branco - fechadura lateral")

        elif Largura <= 150 and Cor == "fosco" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - fosco - fechadura lateral")

        elif Largura <= 150 and Cor == "champanhe" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - champanhe - fechadura lateral")

        elif Largura <= 150 and Cor == "bronze" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - bronze - fechadura lateral")

        elif Largura <= 200 and Cor == "preto" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - preto - fechadura lateral")

        elif Largura <= 200 and Cor == "branco" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - branco - fechadura lateral")

        elif Largura <= 200 and Cor == "fosco" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - fosco - fechadura lateral")

        elif Largura <= 200 and Cor == "champanhe" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - champanhe - fechadura lateral")

        elif Largura <= 200 and Cor == "bronze" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - bronze - fechadura lateral")

        elif Largura <= 200 and Cor == "preto" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - preto - fechadura lateral")

        elif Largura <= 200 and Cor == "branco" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - branco - fechadura lateral")

        elif Largura <= 200 and Cor == "fosco" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - fosco - fechadura lateral")

        elif Largura <= 200 and Cor == "champanhe" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - champanhe - fechadura lateral")

        elif Largura <= 200 and Cor == "bronze" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - bronze - fechadura lateral")

        elif Largura <= 300 and Cor == "preto" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - preto - fechadura lateral")

        elif Largura <= 300 and Cor == "branco" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - branco - fechadura lateral")

        elif Largura <= 300 and Cor == "fosco" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - fosco - fechadura lateral")

        elif Largura <= 300 and Cor == "champanhe" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - champanhe - fechadura lateral")

        elif Largura <= 300 and Cor == "bronze" and Vidro >= 2 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - bronze - fechadura lateral")

        elif Largura <= 300 and Cor == "preto" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - preto - fechadura lateral")

        elif Largura <= 300 and Cor == "branco" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - branco - fechadura lateral")

        elif Largura <= 300 and Cor == "fosco" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - fosco - fechadura lateral")

        elif Largura <= 300 and Cor == "champanhe" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - champanhe - fechadura lateral")

        elif Largura <= 300 and Cor == "bronze" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - bronze - fechadura lateral")

        elif Largura <= 300 and Cor == "preto" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - preto - fechadura lateral")

        elif Largura <= 300 and Cor == "branco" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - branco - fechadura lateral")

        elif Largura <= 300 and Cor == "fosco" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - fosco - fechadura lateral")

        elif Largura <= 300 and Cor == "champanhe" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - champanhe - fechadura lateral")

        elif Largura <= 300 and Cor == "bronze" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - bronze - fechadura lateral")

        elif Largura <= 300 and Cor == "preto" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - preto - fechadura lateral")

        elif Largura <= 300 and Cor == "branco" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - branco - fechadura lateral")

        elif Largura <= 300 and Cor == "fosco" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - fosco - fechadura lateral")

        elif Largura <= 300 and Cor == "champanhe" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - champanhe - fechadura lateral")

        elif Largura <= 300 and Cor == "bronze" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - bronze - fechadura lateral")

        elif Largura <= 400 and Cor == "preto" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - preto - fechadura lateral")

        elif Largura <= 400 and Cor == "branco" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - branco - fechadura lateral")

        elif Largura <= 400 and Cor == "fosco" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - fosco - fechadura lateral")

        elif Largura <= 400 and Cor == "champanhe" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - champanhe - fechadura lateral")

        elif Largura <= 400 and Cor == "bronze" and Vidro >= 3 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - bronze - fechadura lateral")

        elif Largura <= 400 and Cor == "preto" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - preto - fechadura lateral")

        elif Largura <= 400 and Cor == "branco" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - branco - fechadura lateral")

        elif Largura <= 400 and Cor == "fosco" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - fosco - fechadura lateral")

        elif Largura <= 400 and Cor == "champanhe" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - champanhe - fechadura lateral")

        elif Largura <= 400 and Cor == "bronze" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - bronze - fechadura lateral")

        elif Largura <= 400 and Cor == "preto" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - preto - fechadura lateral")

        elif Largura <= 400 and Cor == "branco" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - branco - fechadura lateral")

        elif Largura <= 400 and Cor == "fosco" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - fosco - fechadura lateral")

        elif Largura <= 400 and Cor == "champanhe" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - champanhe - fechadura lateral")

        elif Largura <= 400 and Cor == "bronze" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - bronze - fechadura lateral")

        elif Largura <= 500 and Cor == "preto" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - preto - fechadura lateral")

        elif Largura <= 500 and Cor == "branco" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - branco - fechadura lateral")

        elif Largura <= 500 and Cor == "fosco" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - fosco - fechadura lateral")

        elif Largura <= 500 and Cor == "champanhe" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - champanhe - fechadura lateral")

        elif Largura <= 500 and Cor == "bronze" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - bronze - fechadura lateral")

        elif Largura <= 500 and Cor == "preto" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - preto - fechadura lateral")

        elif Largura <= 500 and Cor == "branco" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - branco - fechadura lateral")

        elif Largura <= 500 and Cor == "fosco" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - fosco - fechadura lateral")

        elif Largura <= 500 and Cor == "champanhe" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - champanhe - fechadura lateral")

        elif Largura <= 500 and Cor == "bronze" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - bronze - fechadura lateral")

        elif Largura <= 500 and Cor == "preto" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - preto - fechadura lateral")

        elif Largura <= 500 and Cor == "branco" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - branco - fechadura lateral")

        elif Largura <= 500 and Cor == "fosco" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - fosco - fechadura lateral")

        elif Largura <= 500 and Cor == "champanhe" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - champanhe - fechadura lateral")

        elif Largura <= 500 and Cor == "bronze" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - bronze - fechadura lateral")

        elif Largura <= 600 and Cor == "preto" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - preto - fechadura lateral")

        elif Largura <= 600 and Cor == "branco" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - branco - fechadura lateral")

        elif Largura <= 600 and Cor == "fosco" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - fosco - fechadura lateral")

        elif Largura <= 600 and Cor == "champanhe" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - champanhe - fechadura lateral")

        elif Largura <= 600 and Cor == "bronze" and Vidro >= 4 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - bronze - fechadura lateral")

        elif Largura <= 600 and Cor == "preto" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - preto - fechadura lateral")

        elif Largura <= 600 and Cor == "branco" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - branco - fechadura lateral")

        elif Largura <= 600 and Cor == "fosco" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - fosco - fechadura lateral")

        elif Largura <= 600 and Cor == "champanhe" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - champanhe - fechadura lateral")

        elif Largura <= 600 and Cor == "bronze" and Vidro >= 5 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - bronze - fechadura lateral")

        elif Largura <= 600 and Cor == "preto" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - preto - fechadura lateral")

        elif Largura <= 600 and Cor == "branco" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - branco - fechadura lateral")

        elif Largura <= 600 and Cor == "fosco" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - fosco - fechadura lateral")

        elif Largura <= 600 and Cor == "champanhe" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - champanhe - fechadura lateral")

        elif Largura <= 600 and Cor == "bronze" and Vidro >= 6 and Fechadura == "lateral":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - bronze - fechadura lateral")

        elif Largura <= 150 and Cor == "preto" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - preto - fechadura central")

        elif Largura <= 150 and Cor == "branco" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - branco - fechadura central")

        elif Largura <= 150 and Cor == "fosco" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - fosco - fechadura central")

        elif Largura <= 150 and Cor == "champanhe" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - champanhe - fechadura central")

        elif Largura <= 150 and Cor == "bronze" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 150 / 2 vidro - bronze - fechadura central")

        elif Largura <= 200 and Cor == "preto" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - preto - fechadura central")

        elif Largura <= 200 and Cor == "branco" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - branco - fechadura central")

        elif Largura <= 200 and Cor == "fosco" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - fosco - fechadura central")

        elif Largura <= 200 and Cor == "champanhe" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - champanhe - fechadura central")

        elif Largura <= 200 and Cor == "bronze" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - bronze - fechadura central")

        elif Largura <= 200 and Cor == "preto" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - preto - fechadura central")

        elif Largura <= 200 and Cor == "branco" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - branco - fechadura central")

        elif Largura <= 200 and Cor == "fosco" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - fosco - fechadura central")

        elif Largura <= 200 and Cor == "champanhe" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - champanhe - fechadura central")

        elif Largura <= 200 and Cor == "bronze" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 200 / 3 vidro - bronze - fechadura central")

        elif Largura <= 300 and Cor == "preto" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - preto - fechadura central")

        elif Largura <= 300 and Cor == "branco" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - branco - fechadura central")

        elif Largura <= 300 and Cor == "fosco" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - fosco - fechadura central")

        elif Largura <= 300 and Cor == "champanhe" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - champanhe - fechadura central")

        elif Largura <= 300 and Cor == "bronze" and Vidro >= 2 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 2 vidro - bronze - fechadura central")

        elif Largura <= 300 and Cor == "preto" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - preto - fechadura central")

        elif Largura <= 300 and Cor == "branco" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - branco - fechadura central")

        elif Largura <= 300 and Cor == "fosco" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - fosco - fechadura central")

        elif Largura <= 300 and Cor == "champanhe" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - champanhe - fechadura central")

        elif Largura <= 300 and Cor == "bronze" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 3 vidro - bronze - fechadura central")

        elif Largura <= 300 and Cor == "preto" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - preto - fechadura central")

        elif Largura <= 300 and Cor == "branco" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - branco - fechadura central")

        elif Largura <= 300 and Cor == "fosco" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - fosco - fechadura central")

        elif Largura <= 300 and Cor == "champanhe" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - champanhe - fechadura central")

        elif Largura <= 300 and Cor == "bronze" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 4 vidro - bronze - fechadura central")

        elif Largura <= 300 and Cor == "preto" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - preto - fechadura central")

        elif Largura <= 300 and Cor == "branco" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - branco - fechadura central")

        elif Largura <= 300 and Cor == "fosco" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - fosco - fechadura central")

        elif Largura <= 300 and Cor == "champanhe" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - champanhe - fechadura central")

        elif Largura <= 300 and Cor == "bronze" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 300 / 5 vidro - bronze - fechadura central")

        elif Largura <= 400 and Cor == "preto" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - preto - fechadura central")

        elif Largura <= 400 and Cor == "branco" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - branco - fechadura central")

        elif Largura <= 400 and Cor == "fosco" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - fosco - fechadura central")

        elif Largura <= 400 and Cor == "champanhe" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - champanhe - fechadura central")

        elif Largura <= 400 and Cor == "bronze" and Vidro >= 3 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 3 vidro - bronze - fechadura central")

        elif Largura <= 400 and Cor == "preto" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - preto - fechadura central")

        elif Largura <= 400 and Cor == "branco" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - branco - fechadura central")

        elif Largura <= 400 and Cor == "fosco" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - fosco - fechadura central")

        elif Largura <= 400 and Cor == "champanhe" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - champanhe - fechadura central")

        elif Largura <= 400 and Cor == "bronze" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 4 vidro - bronze - fechadura central")

        elif Largura <= 400 and Cor == "preto" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - preto - fechadura central")

        elif Largura <= 400 and Cor == "branco" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - branco - fechadura central")

        elif Largura <= 400 and Cor == "fosco" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - fosco - fechadura central")

        elif Largura <= 400 and Cor == "champanhe" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - champanhe - fechadura central")

        elif Largura <= 400 and Cor == "bronze" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 400 / 5 vidro - bronze - fechadura central")

        elif Largura <= 500 and Cor == "preto" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - preto - fechadura central")

        elif Largura <= 500 and Cor == "branco" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - branco - fechadura central")

        elif Largura <= 500 and Cor == "fosco" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - fosco - fechadura central")

        elif Largura <= 500 and Cor == "champanhe" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - champanhe - fechadura central")

        elif Largura <= 500 and Cor == "bronze" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 4 vidro - bronze - fechadura central")

        elif Largura <= 500 and Cor == "preto" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - preto - fechadura central")

        elif Largura <= 500 and Cor == "branco" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - branco - fechadura central")

        elif Largura <= 500 and Cor == "fosco" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - fosco - fechadura central")

        elif Largura <= 500 and Cor == "champanhe" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - champanhe - fechadura central")

        elif Largura <= 500 and Cor == "bronze" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 5 vidro - bronze - fechadura central")

        elif Largura <= 500 and Cor == "preto" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - preto - fechadura central")

        elif Largura <= 500 and Cor == "branco" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - branco - fechadura central")

        elif Largura <= 500 and Cor == "fosco" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - fosco - fechadura central")

        elif Largura <= 500 and Cor == "champanhe" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - champanhe - fechadura central")

        elif Largura <= 500 and Cor == "bronze" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 500 / 6 vidro - bronze - fechadura central")

        elif Largura <= 600 and Cor == "preto" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - preto - fechadura central")

        elif Largura <= 600 and Cor == "branco" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - branco - fechadura central")

        elif Largura <= 600 and Cor == "fosco" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - fosco - fechadura central")

        elif Largura <= 600 and Cor == "champanhe" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - champanhe - fechadura central")

        elif Largura <= 600 and Cor == "bronze" and Vidro >= 4 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 4 vidro - bronze - fechadura central")

        elif Largura <= 600 and Cor == "preto" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - preto - fechadura central")

        elif Largura <= 600 and Cor == "branco" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - branco - fechadura central")

        elif Largura <= 600 and Cor == "fosco" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - fosco - fechadura central")

        elif Largura <= 600 and Cor == "champanhe" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - champanhe - fechadura central")

        elif Largura <= 600 and Cor == "bronze" and Vidro >= 5 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 5 vidro - bronze - fechadura central")

        elif Largura <= 600 and Cor == "preto" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - preto - fechadura central")

        elif Largura <= 600 and Cor == "branco" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - branco - fechadura central")

        elif Largura <= 600 and Cor == "fosco" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - fosco - fechadura central")

        elif Largura <= 600 and Cor == "champanhe" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - champanhe - fechadura central")

        elif Largura <= 600 and Cor == "bronze" and Vidro >= 6 and Fechadura == "central":
            print("PERFIL EVIDENCE DOOR 8MM 600 / 6 vidro - bronze - fechadura central")

        break
    break

# Fechar a conexão
conn.close()
import sqlite3

# Conectar ao banco de dados (se o banco não existir, ele será criado)
conn = sqlite3.connect('meu_banco.db')

# Criar um cursor
cursor = conn.cursor()

# Criar uma tabela
cursor.execute('''
CREATE TABLE IF NOT EXISTS usuario (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nome TEXT,
    projetos TEXT
)
''')

# Inserir dados
cursor.execute("INSERT INTO usuario (nome, projetos) VALUES (?, ?)", ("joao", 50))
conn.commit()

# Consultar dados
cursor.execute("SELECT * FROM usuario")
usuarios = cursor.fetchall()

for usuario in usuarios:
    print(usuario)

# Fechar a conexão
conn.close()
# Out:
# Digite a largura do vão em centimetro: 200
#
# === Escolha a cor do Kit ===
# 1. preto
# 2. branco
# 3. fosco
# 4. champanhe
# 5. bronze
# Digite a cor do kit evidence door: preto
# Digite a quantidade de vidro: 2
#
# === Escolha modelo da fechadura ===
# 1. lateral
# 2. central
# Digite a posição da fechadura: lateral
# PERFIL EVIDENCE DOOR 8MM 200 / 2 vidro - preto - fechadura lateral
# (1, 'luis', '32')
# (2, 'joao', '50')
# (3, 'joao', '50')
# (4, 'joao', '50')
# (5, 'joao', '50')
# (6, 'joao', '50')
